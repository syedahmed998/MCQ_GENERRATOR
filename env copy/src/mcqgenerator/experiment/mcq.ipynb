# %%
import sys 
# !{sys.executable} -m pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-3.0.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\hp\anaconda3\envs\genai\Lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\hp\anaconda3\envs\genai\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\hp\anaconda3\envs\genai\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\Users\hp\anaconda3\envs\genai\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.3-cp311-cp311-win_amd64.whl (9.9 MB)
# Installing collected packages: pandas
# Successfully installed pandas-3.0.3

# %%
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser

# %%
KEY=os.g

# %%
groq_apikey="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"
llm=ChatGroq(model="llama-3.1-8b-instant",
            api_key=groq_apikey,
            temperature=0.5,
            max_tokens=40)

# %%
import os
import json
import pandas as pd
import traceback
